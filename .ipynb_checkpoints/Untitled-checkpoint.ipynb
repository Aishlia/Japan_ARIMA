# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import acf, pacf
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
nk = pd.read_csv("Nikkei_monthly_10.csv", usecols=["Price_Nikkei"])
nk['Price_Nikkei'] = np.log(nk['Price_Nikkei'].str.replace(',','').astype(float))
nk.plot()
plt.show()

# %%
autocorrelation_plot(nk)
plt.show()

# %%
nk_matrix = nk.as_matrix()

# Fit model
model = ARIMA(nk_matrix, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())

# Plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  119
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                 171.180
# Method:                       css-mle   S.D. of innovations              0.057
# Date:                Tue, 08 May 2018   AIC                           -328.360
# Time:                        12:47:41   BIC                           -308.906
# Sample:                             1   HQIC                          -320.460
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0040      0.007     -0.591      0.556      -0.017       0.009
# ar.L1.D.y      0.2005      0.091      2.195      0.030       0.021       0.380
# ar.L2.D.y     -0.0868      0.093     -0.933      0.353      -0.269       0.096
# ar.L3.D.y      0.0932      0.094      0.990      0.324      -0.091       0.278
# ar.L4.D.y     -0.0003      0.104     -0.003      0.998      -0.203       0.203
# ar.L5.D.y      0.0169      0.102      0.165      0.869      -0.184       0.218
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.8353           -0.0000j            1.8353           -0.0000
# AR.2           -1.3683           -1.8970j            2.3390           -0.3495
# AR.3           -1.3683           +1.8970j            2.3390            0.3495
# AR.4            0.4595           -2.3843j            2.4282           -0.2197
# AR.5            0.4595           +2.3843j            2.4282            0.2197
# -----------------------------------------------------------------------------
#                 0
# count  119.000000
# mean    -0.000031
# std      0.057645
# min     -0.117510
# 25%     -0.040699
# 50%     -0.006894
# 75%      0.029723
# max      0.261897

# %%
X = nk.values
size = 1 #int(len(X) * .66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()

ctr = 0

for time_step in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[time_step]
    history.append(obs)
    print('%.f) predicted=%f, expected=%f' % (time_step, yhat, obs))
    
error = mean_squared_error(test, predictions)
print('Test MSE:', error)

# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# 0) predicted=9.496782, expected=9.530577
# 1) predicted=9.528433, expected=9.536824
# 2) predicted=9.513705, expected=9.425283
# 3) predicted=9.417051, expected=9.355251
# 4) predicted=9.354678, expected=9.318177
# 5) predicted=9.318342, expected=9.249098
# 6) predicted=9.248764, expected=9.153348
# 7) predicted=9.114780, expected=9.096980
# 8) predicted=9.068135, expected=9.090448
# 9) predicted=9.074859, expected=9.087032
# 10) predicted=9.065536, expected=9.070510
# 11) predicted=9.042044, expected=9.105733
# 12) predicted=9.092851, expected=9.052836
# 13) predicted=9.031883, expected=9.161244
# 14) predicted=9.163306, expected=9.218662
# 15) predicted=9.207029, expected=9.182274
# 16) predicted=9.181442, expected=9.082792
# 17) predicted=9.050445, expected=9.042555
# 18) predicted=9.049959, expected=9.040099
# 19) predicted=9.043888, expected=9.103689
# 20) predicted=9.102900, expected=9.071112
# 21) predicted=9.035893, expected=9.099990
# 22) predicted=9.086924, expected=9.193502
# 23) predicted=9.193646, expected=9.191778
# 24) predicted=9.184553, expected=9.179235
# 25) predicted=9.164174, expected=9.195200
# 26) predicted=9.191394, expected=9.185546
# 27) predicted=9.185886, expected=9.270879
# 28) predicted=9.277578, expected=9.233854
# 29) predicted=9.213439, expected=9.232974
# 30) predicted=9.231619, expected=9.204024
# 31) predicted=9.189959, expected=9.127225
# 32) predicted=9.127463, expected=9.145199
# 33) predicted=9.137912, expected=9.085237
# 34) predicted=9.070604, expected=9.162966
# 35) predicted=9.163123, expected=9.146616
# 36) predicted=9.122195, expected=9.186939
# 37) predicted=9.184875, expected=9.310855
# 38) predicted=9.300026, expected=9.313794
# 39) predicted=9.323016, expected=9.222865
# 40) predicted=9.199777, expected=9.229951
# 41) predicted=9.226442, expected=9.263544
# 42) predicted=9.276760, expected=9.142656
# 43) predicted=9.127397, expected=9.213808
# 44) predicted=9.211419, expected=9.223575
# 45) predicted=9.202997, expected=9.258419
# 46) predicted=9.264913, expected=9.245401
# 47) predicted=9.223592, expected=9.206176
# 48) predicted=9.203430, expected=9.161413
# 49) predicted=9.151767, expected=9.085713
# 50) predicted=9.077560, expected=9.000795
# 51) predicted=8.989582, expected=8.931740
# 52) predicted=8.917221, expected=8.986453
# 53) predicted=8.986630, expected=9.089252
# 54) predicted=9.093060, expected=9.049264
# 55) predicted=9.032020, expected=9.056837
# 56) predicted=9.044568, expected=9.328999
# 57) predicted=9.340950, expected=9.478294
# 58) predicted=9.478676, expected=9.501278
# 59) predicted=9.516126, expected=9.509065
# Test MSE: 0.00512821905177
